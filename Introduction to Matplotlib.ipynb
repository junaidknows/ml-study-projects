# %% [markdown]
# ## Introduction to Matplotlib

# %% [markdown]
# ![Matplotlib Workflow](matplotlib-workflow.png)

# %%
# %matplotlib inline 
# Using magic command, so it will appear in the notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Simplest way to create a plot in Matplotlib
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y)
plt.show()

# %%
#1st way to create a figure and axes
fig = plt.figure() # Creates a figure
ax = fig.add_subplot() # Adds some axes
plt.show()

# %%
#2ns way to create a figure and axes
fig = plt.figure() # creates a figure
ax = fig.add_axes([1,1,1,1]) # Adds some axes
ax.plot(x, y) # Adds some data
plt.show()

# %%
#3rd way to create a figure and axes (recommended)
fig, ax = plt.subplots()
ax.plot(x, y) # Adds some data
plt.show()

# %%
# Another example of the 3rd method
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250]) # Plotting data
plt.show()

# %% [markdown]
# ![Anatomy of a Matplotlib plot](anatomy-of-a-matplotlib-plot1.png)

# %% [markdown]
# ![Anatomy of Matplotlib Plot with Code](anatomy-of-a-matplotlib-plot2-wcode.png)

# %%
#Object oriented interface
fig, ax = plt.subplots()
ax.plot(x, y) # Adds some data
ax.set(title="Simple Plot", xlabel="x-axis", ylabel="y-axis")
plt.show()
type(fig), type(ax)

#Type shows that fig is a figure and ax is an axes which is object oriented interface of matplotlib library
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ### Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

#1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

#2. Setup plot # we will use the object oriented method
fig, ax = plt.subplots(figsize=(10, 10)) # Width, height #it's the dimensions of the plot figzie

#3. Plot data
ax.plot(x, y)

#4. Customize plot
ax.set(title="Simple Plot", 
       xlabel="x-axis",
         ylabel="y-axis")

#5. Save & show (you save the whole figure)
fig.savefig("sample-plot1.png")

# %% [markdown]
# ### Making figures with NumPy arrays
#
# #### Some main types of Plot that we're going to create in this notebook
# - Line Plot
# - Scatter Plot
# - Bar Plot
# - Histogram also known as *Hist*
# - Subplots

# %%
import numpy as np

# %%
#create some data
x = np.linspace(0, 10, 100)
x[:10] # First 10 elements of x
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a line plot and it's a default plot
fig, ax = plt.subplots()
ax.plot(x, x**2)
plt.show()

# %%
#Use the same data to make a scatter 
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x)) # np.exp(x) is the exponential of x
plt.show()

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x)) # np.sin(x) is the sine of x
plt.show()

# %%
# Make a plot from dictionary of Python not from numpy array
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}
fix, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Nut Butter Store", ylabel="Price ($)")
plt.show()

# %% [markdown]
# ## Horizontal bar plot

# %%
#Created a horizontal bar plot using the same data from a python dictionary

nut_butter_prices = {"Almond butter": 10,
                        "Peanut butter": 8,
                        "Cashew butter": 12}
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values())) #ax.barh() is used to create a horizontal bar plot and list is used to convert the dictionary keys and values into a list
ax.set(title="Nut Butter Store", xlabel="Price ($)")
plt.show()

# %%
# Create some data for histograms and plot it
x = np.random.randn(1000) # randn is used to generate random numbers
fig, ax = plt.subplots() # Create a figure and axes
ax.hist(x) # Plot a histogram
plt.show()

# %% [markdown]
# ## Two options for subplots

# %%
# Subplot option 1 , we have tuple in our subplot
# nrows and ncols and figsize are the keyword arguments
# nrows is the number of rows of subplots
# ncols is the number of columns of subplots
# figsize is the dimensions of the plot


fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10, 5))


# Commneted out the code because it will not work in the same cell, we're adding the data to each plot below
#plt.show()

# Plot to each different axis
ax1.plot(x, x/2) # Line plot
ax1.set(title="Line Plot")

# Add spacing between plots
plt.tight_layout()

# Plot to 2nd axis
ax2.scatter(np.random.random(10), np.random.random(10)) # Scatter plot
ax2.set(title="Scatter Plot")

# Add spacing between plots
plt.tight_layout()

# Plot to 3rd axis
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values()) # Bar plot
ax3.set(title="Bar Plot")

# Add spacing between plots
plt.tight_layout()

# Plot to 4th axis
ax4.hist(np.random.randn(1000)) # Histogram
ax4.set(title="Histogram")
plt.show()

# %% [markdown]
# ### Subploting Option 2

# %%
# Subplot option 2, this is kind of list index way and option 1 was tuple way

fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                          figsize=(10, 5))

# Plot to each different index
ax[0,0].plot(x, x/2) # Line plot
ax[0,0].set(title="Line Plot")

#Add spacing between plots
plt.tight_layout()

ax[0,1].scatter(np.random.random(10), np.random.random(10)) # Scatter plot
ax[0,1].set(title="Scatter Plot")

# Add spacing between plots
plt.tight_layout()

ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values()) # Bar plot
ax[1,0].set(title="Bar Plot")

# Add spacing between plots
plt.tight_layout()

ax[1,1].hist(np.random.randn(1000)) # Histogram
ax[1,1].set(title="Histogram")

plt.show()

# %% [markdown]
# ### Data Visualizations

# %% [markdown]
# **Just because we have data that doesn't mean we have knowledge**

# %% [markdown]
# ##### Plotting From Pandas **Data Frames**

# %%
import pandas as pd

# %%
# Make a datafame, we have a file called car_sales.csv which we have used previously, we are going to use it again

car_sales = pd.read_csv("car_sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range("1/1/2020", periods=1000))
ts = ts.cumsum() # cumsum() is used to calculate the cumulative sum of a series
ts.plot()
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].astype(str).str.replace(r'[\$\,]', "", regex=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   4000.00
# 1   Honda    Red          87899      4   5000.00
# 2  Toyota   Blue          32549      3   7000.00
# 3     BMW  Black          11179      5  22000.00
# 4  Nissan  White         213095      4   3500.00
# 5  Toyota  Green          99213      4   4500.00
# 6   Honda   Blue          45698      4   7500.00
# 7   Honda   Blue          54738      4   7000.00
# 8  Toyota  White          60000      4   6250.00
# 9  Nissan  White          31600      4   9700.00

# %%
# Removed the $ in the above section, now we will convert the Price column to integer from string but it couldn't be directly converted to integer 
# because it has a decimal point in it so we will convert it to float first and then to integer

car_sales["Price"] = car_sales["Price"].astype(float).astype(int)
car_sales["Price"].dtype
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
#Adding a date column to the car_sales dataframe

car_sales["Sale Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
# We need a total sales column which is the cumulative sum of the Price column
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
# Plot the total sales
car_sales.plot(x="Sale Date", y="Total Sales")
plt.show()

# %%
#Scatter plot with price column as numeric and Odometer column as numeric
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
plt.show()

# %%
#Let's create a bar graph

x = np.random.rand(10, 4)
x

#Turn it into a dataframe
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.451759  0.857624  0.477303  0.702719
# 1  0.612429  0.062219  0.352762  0.738160
# 2  0.384547  0.676011  0.659785  0.662095
# 3  0.579201  0.174793  0.523198  0.862069
# 4  0.785646  0.406041  0.051175  0.183151
# 5  0.408784  0.483537  0.681386  0.931293
# 6  0.194337  0.382006  0.831443  0.986211
# 7  0.156282  0.989107  0.691899  0.560926
# 8  0.477326  0.959215  0.632122  0.965699
# 9  0.487838  0.828728  0.648973  0.464713

# %%
#Let's plot the bar graph of the dataframe
df.plot.bar()
plt.show()

# %%
df.plot(kind="bar") # Another way to plot a bar graph
plt.show()

# %% [markdown]
# # Let's plot the bar graph of the car_sales dataframe

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Make", y = "Odometer (KM)", kind="bar") # Bar graph of car_sales dataframe
plt.show()

# %%
# Histogram of the Odometer column
car_sales["Odometer (KM)"].plot.hist()
plt.show()

# %%
car_sales["Odometer (KM)"].plot(kind="hist") # Another way to plot a histogram
plt.show()

# %%
# Bin is used to set the number of bins in the histogram
car_sales["Odometer (KM)"].plot.hist(bins=20)
plt.show()

# %%
# Let's try on another dataset from our directory
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head() # First 5 rows of the dataset
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
